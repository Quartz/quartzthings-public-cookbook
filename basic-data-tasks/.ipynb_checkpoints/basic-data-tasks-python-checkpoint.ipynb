# %% [markdown]
# # Basic data tasks using Python and pandas
# This tutorial will show you how to do the following
#
# * [Loading libraries](#Loading-libraries)
# * [Loading data](#Loading-data)
# * [Preview data](#Preview-data)
# * [Clean up column names](#Clean-up-column-names)
# * [Dropping columns](#Dropping-columns)
# * [Selecting columns](#Selecting-columns)
# * [Limit the data by one factor](#Limit-the-data-by-one-factor)
# * [Limit the data by two factors](#Limit-the-data-by-two-factors)
# * [Sorting](#Sorting)
# * [Find unique values](#Find-unique-values)
# * [Summarize the data](#Summarize-the-data)
# * [Summarize groups of the data](#Summarize-groups-of-the-data)
# * [Transforming and adding columns](#Transforming-and-adding-columns)
# * [Putting it all together](#Putting-it-all-together)
# * [Pivoting the data (and more)](#Pivoting-the-data-(and-more))
# * [Saving your data](#Saving-your-data)
# * [Joining data](#Joining-data)
#
# Run this code in the console to generate the index if it changes...
#
# ```copy([...document.querySelectorAll("h2")].map(d => `* [${d.textContent.replace("¶","")}](#${d.querySelector("a").href.split("#")[1]})`).join("\n"))```

# %% [markdown]
# ## Loading libraries
# These are software packages that are specifically designed to do data analysis in python. They make working with data much easier.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading data
#
# We're using data from the USDA's Agricultural Marketing Service on [advertised retail food prices](https://marketnews.usda.gov/mnp/fv-report-retail?category=retail&portal=fv&startIndex=1&class=ALL&region=NATIONAL&organic=ALL&commodity=ALL&reportConfig=true&dr=1&repType=wiz&step2=true&run=Run&type=retail&commodityClass=allcommodity)

# %%
# load a csv and store it as the variable df
df = pd.read_csv("usda-ams-retail-fruit-and-vegetables_201809-201909.csv")

# %% [markdown]
# ## Preview data
# This is how you can look at couple rows of data

# %%
# show the first 5 rows
df.head()
# Out:
#          Date    Region   Class    Commodity   Variety Organic Environment  \
# 0  09/07/2018  NATIONAL  FRUITS  APPLE PEARS       NaN     NaN         NaN
# 1  09/07/2018  NATIONAL  FRUITS       APPLES  BRAEBURN     NaN         NaN
# 2  09/07/2018  NATIONAL  FRUITS       APPLES      FUJI     NaN         NaN
# 3  09/07/2018  NATIONAL  FRUITS       APPLES      FUJI     NaN         NaN
# 4  09/07/2018  NATIONAL  FRUITS       APPLES      FUJI     NaN         NaN
#
#         Unit  Number of Stores  Weighted Avg Price  Low Price  High Price  \
# 0       each               264                1.49        NaN         NaN
# 1  per pound                53                1.11        NaN         NaN
# 2   2 lb bag                55                1.99        NaN         NaN
# 3   3 lb bag               593                3.49        NaN         NaN
# 4  per pound              1349                1.11        NaN         NaN
#
#    % Marked Local
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# Show the first 3 rows
df.head(3)
# Out:
#          Date    Region   Class    Commodity   Variety Organic Environment  \
# 0  09/07/2018  NATIONAL  FRUITS  APPLE PEARS       NaN     NaN         NaN
# 1  09/07/2018  NATIONAL  FRUITS       APPLES  BRAEBURN     NaN         NaN
# 2  09/07/2018  NATIONAL  FRUITS       APPLES      FUJI     NaN         NaN
#
#         Unit  Number of Stores  Weighted Avg Price  Low Price  High Price  \
# 0       each               264                1.49        NaN         NaN
# 1  per pound                53                1.11        NaN         NaN
# 2   2 lb bag                55                1.99        NaN         NaN
#
#    % Marked Local
# 0             NaN
# 1             NaN
# 2             NaN

# %%
# show rows 10, 11, and 12
df[9:12]
# Out:
#           Date    Region   Class Commodity Variety Organic Environment  \
# 9   09/07/2018  NATIONAL  FRUITS    APPLES    GALA     NaN         NaN
# 10  09/07/2018  NATIONAL  FRUITS    APPLES    GALA       Y         NaN
# 11  09/07/2018  NATIONAL  FRUITS    APPLES    GALA       Y         NaN
#
#          Unit  Number of Stores  Weighted Avg Price  Low Price  High Price  \
# 9   per pound              7343                1.30        NaN         NaN
# 10   2 lb bag              1330                3.90        NaN         NaN
# 11   3 lb bag               311                4.35        NaN         NaN
#
#     % Marked Local
# 9              NaN
# 10             NaN
# 11             NaN

# %% [markdown]
# ## Clean up column names
#
# Notice the outermost parens; Those let you format your piped/chained methods on multiple lines in python

# %%
df_clean_headers = (df
     .rename(columns=lambda x: x.replace("% ", ""))
     .rename(columns=str.lower)
     .rename(columns=lambda x: x.replace(" ", "_"))
)

df_clean_headers.head()
# Out:
#          date    region   class    commodity   variety organic environment  \
# 0  09/07/2018  NATIONAL  FRUITS  APPLE PEARS       NaN     NaN         NaN
# 1  09/07/2018  NATIONAL  FRUITS       APPLES  BRAEBURN     NaN         NaN
# 2  09/07/2018  NATIONAL  FRUITS       APPLES      FUJI     NaN         NaN
# 3  09/07/2018  NATIONAL  FRUITS       APPLES      FUJI     NaN         NaN
# 4  09/07/2018  NATIONAL  FRUITS       APPLES      FUJI     NaN         NaN
#
#         unit  number_of_stores  weighted_avg_price  low_price  high_price  \
# 0       each               264                1.49        NaN         NaN
# 1  per pound                53                1.11        NaN         NaN
# 2   2 lb bag                55                1.99        NaN         NaN
# 3   3 lb bag               593                3.49        NaN         NaN
# 4  per pound              1349                1.11        NaN         NaN
#
#    marked_local
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %% [markdown]
# ## Dropping columns

# %%
cols_to_drop = [
    "environment",
    "low_price", 
    "high_price", 
    "marked_local"
]

df_clean_headers.drop(cols_to_drop, axis=1).head()
# Out:
#          date    region   class    commodity   variety organic       unit  \
# 0  09/07/2018  NATIONAL  FRUITS  APPLE PEARS       NaN     NaN       each
# 1  09/07/2018  NATIONAL  FRUITS       APPLES  BRAEBURN     NaN  per pound
# 2  09/07/2018  NATIONAL  FRUITS       APPLES      FUJI     NaN   2 lb bag
# 3  09/07/2018  NATIONAL  FRUITS       APPLES      FUJI     NaN   3 lb bag
# 4  09/07/2018  NATIONAL  FRUITS       APPLES      FUJI     NaN  per pound
#
#    number_of_stores  weighted_avg_price
# 0               264                1.49
# 1                53                1.11
# 2                55                1.99
# 3               593                3.49
# 4              1349                1.11

# %% [markdown]
# ## Selecting columns

# %%
cols_to_select = [
    "date",
    "variety",
    "organic",
    "unit",
    "number_of_stores",
    "weighted_avg_price"
]
df_clean_headers[cols_to_select].head()
# Out:
#          date   variety organic       unit  number_of_stores  \
# 0  09/07/2018       NaN     NaN       each               264
# 1  09/07/2018  BRAEBURN     NaN  per pound                53
# 2  09/07/2018      FUJI     NaN   2 lb bag                55
# 3  09/07/2018      FUJI     NaN   3 lb bag               593
# 4  09/07/2018      FUJI     NaN  per pound              1349
#
#    weighted_avg_price
# 0                1.49
# 1                1.11
# 2                1.99
# 3                3.49
# 4                1.11

# %% [markdown]
# ## Limit the data by one factor

# %%
# filter the data to only be apples
(df_clean_headers[
    df_clean_headers.commodity == "APPLES"
    ]
).tail()
# Out:
#              date  region   class commodity variety organic environment  \
# 86195  08/30/2019  HAWAII  FRUITS    APPLES    FUJI     NaN         NaN
# 86196  08/30/2019  ALASKA  FRUITS    APPLES    FUJI       Y         NaN
# 86197  08/30/2019  ALASKA  FRUITS    APPLES    GALA     NaN         NaN
# 86198  08/30/2019  ALASKA  FRUITS    APPLES    GALA     NaN         NaN
# 86199  08/30/2019  HAWAII  FRUITS    APPLES    GALA     NaN         NaN
#
#             unit  number_of_stores  weighted_avg_price  low_price  high_price  \
# 86195  per pound                13                1.63       1.48        1.79
# 86196  per pound                 1                2.59       2.59        2.59
# 86197   5 lb bag                 7                6.99       6.99        6.99
# 86198  per pound                10                1.78       1.78        1.78
# 86199  per pound                10                1.78       1.78        1.78
#
#        marked_local
# 86195           NaN
# 86196           NaN
# 86197           NaN
# 86198           NaN
# 86199           NaN

# %% [markdown]
# **A quick note about selecting columns:** these two methods are equivalent. You can use dot notation or bracket notation to select a single column

# %%
(
    df_clean_headers.commodity == df_clean_headers["commodity"]
).all() # this evaluates as true if all element pairs evaluate as equal
# Out:
# True

# %% [markdown]
# ## Limit the data by two factors
# There are lots of way to do this!
#
# **Here's a straight-forward, but longwinded and persnickity way** (look at those parens)

# %%
# filter the data to only be apples at the National aggregation
(df_clean_headers[
    (df_clean_headers.commodity == "APPLES") &
    (df_clean_headers.region == "NATIONAL")
    ]
).head(2)
# Out:
#          date    region   class commodity   variety organic environment  \
# 1  09/07/2018  NATIONAL  FRUITS    APPLES  BRAEBURN     NaN         NaN
# 2  09/07/2018  NATIONAL  FRUITS    APPLES      FUJI     NaN         NaN
#
#         unit  number_of_stores  weighted_avg_price  low_price  high_price  \
# 1  per pound                53                1.11        NaN         NaN
# 2   2 lb bag                55                1.99        NaN         NaN
#
#    marked_local
# 1           NaN
# 2           NaN

# %% [markdown]
# **This is a way using built in pandas methods** (notice how it doesn't need parens)

# %%
(df_clean_headers[
    df_clean_headers.commodity.str.match("APPLES") &
    df_clean_headers.region.str.match("NATIONAL")
    ]
).head(2)
# Out:
#          date    region   class commodity   variety organic environment  \
# 1  09/07/2018  NATIONAL  FRUITS    APPLES  BRAEBURN     NaN         NaN
# 2  09/07/2018  NATIONAL  FRUITS    APPLES      FUJI     NaN         NaN
#
#         unit  number_of_stores  weighted_avg_price  low_price  high_price  \
# 1  per pound                53                1.11        NaN         NaN
# 2   2 lb bag                55                1.99        NaN         NaN
#
#    marked_local
# 1           NaN
# 2           NaN

# %% [markdown]
# **This is a more SQL-like way to do the same filter** It is also the easiest to read (especially when chaining/piping) and the fastest.

# %%
nat_apples = (df_clean_headers
    .query("region == 'NATIONAL' & commodity == 'APPLES'")
)

nat_apples.head()
# Out:
#          date    region   class commodity   variety organic environment  \
# 1  09/07/2018  NATIONAL  FRUITS    APPLES  BRAEBURN     NaN         NaN
# 2  09/07/2018  NATIONAL  FRUITS    APPLES      FUJI     NaN         NaN
# 3  09/07/2018  NATIONAL  FRUITS    APPLES      FUJI     NaN         NaN
# 4  09/07/2018  NATIONAL  FRUITS    APPLES      FUJI     NaN         NaN
# 5  09/07/2018  NATIONAL  FRUITS    APPLES      FUJI       Y         NaN
#
#         unit  number_of_stores  weighted_avg_price  low_price  high_price  \
# 1  per pound                53                1.11        NaN         NaN
# 2   2 lb bag                55                1.99        NaN         NaN
# 3   3 lb bag               593                3.49        NaN         NaN
# 4  per pound              1349                1.11        NaN         NaN
# 5  per pound                59                2.74        NaN         NaN
#
#    marked_local
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN

# %% [markdown]
# ## Sorting

# %%
(
    # sort by wap from large to small
    nat_apples.sort_values("weighted_avg_price", ascending=False)
    
    # filter to just the relevant columns
    [["date", "variety", "unit", "weighted_avg_price"]]
).head(10)
# Out:
#              date                variety      unit  weighted_avg_price
# 16105  11/09/2018                   FUJI  3 lb bag                8.13
# 7154   10/05/2018             HONEYCRISP  3 lb bag                6.99
# 51534  04/05/2019           GRANNY SMITH  3 lb bag                6.99
# 33143  01/18/2019  PINK LADY/CRIPPS PINK  3 lb bag                6.99
# 34855  01/25/2019           GRANNY SMITH  3 lb bag                6.99
# 12557  10/26/2018             HONEYCRISP  3 lb bag                6.99
# 84726  08/30/2019                   GALA  5 lb bag                6.99
# 33127  01/18/2019           GRANNY SMITH  3 lb bag                6.99
# 10749  10/19/2018             HONEYCRISP  3 lb bag                6.99
# 8954   10/12/2018             HONEYCRISP  3 lb bag                6.99

# %% [markdown]
# ## Find unique values

# %%
print("Unique units:")
print(nat_apples.unit.unique())

print("\nUnique varieties:")
print(nat_apples.variety.unique())
# Out:
# Unique units:
# ['per pound' '2 lb bag' '3 lb bag' '5 lb bag']
#
# Unique varieties:
# ['BRAEBURN' 'FUJI' 'GALA' 'GINGER GOLD' 'GOLDEN DELICIOUS' 'GRANNY SMITH'
#  'HONEYCRISP' 'JONAGOLD' 'JONATHAN' 'MCINTOSH' 'PAULA RED'
#  'PINK LADY/CRIPPS PINK' 'RED DELICIOUS' 'ROME']

# %% [markdown]
# ## Summarize the data

# %%
nat_apples.describe()
# Out:
#        number_of_stores  weighted_avg_price  low_price  high_price  \
# count       2062.000000         2062.000000        0.0         0.0
# mean         692.643065            2.713598        NaN         NaN
# std         1273.126278            1.247909        NaN         NaN
# min            1.000000            0.250000        NaN         NaN
# 25%           46.000000            1.700000        NaN         NaN
# 50%          219.000000            2.500000        NaN         NaN
# 75%          789.000000            3.500000        NaN         NaN
# max        12056.000000            8.130000        NaN         NaN
#
#        marked_local
# count           0.0
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %% [markdown]
# ## Summarize groups of the data
# Let's rank the variety of apples by the lowest national advertised price average

# %%
(nat_apples
 
 # group the data by apple type
 .groupby("variety")
 
 # summarize the data
 .describe()
 
 # summarizing a group creates a multi-index frame
 # so we have to specify a tuple to sort on
 # a specific column
 .sort_values([("weighted_avg_price", "min")])
 
 # limit the frame to only the WAP summary
 [["weighted_avg_price"]]
)
# Out:
#                       weighted_avg_price                                    \
#                                    count      mean       std   min     25%
# variety
# ROME                                62.0  1.983226  0.909991  0.25  1.1625
# GINGER GOLD                         29.0  2.077931  1.016167  0.58  1.1400
# JONATHAN                            52.0  2.312885  0.858447  0.74  1.5100
# PINK LADY/CRIPPS PINK              169.0  2.692840  1.231585  0.74  1.7200
# MCINTOSH                           119.0  2.273950  0.993446  0.78  1.4150
# BRAEBURN                           120.0  2.153750  1.148314  0.79  1.3200
# GRANNY SMITH                       233.0  3.054120  1.343118  0.79  1.8900
# JONAGOLD                            88.0  2.030227  1.018624  0.79  1.2000
# GOLDEN DELICIOUS                   149.0  2.317987  0.947722  0.88  1.5200
# RED DELICIOUS                      271.0  2.784723  1.226260  0.88  1.8500
# PAULA RED                           15.0  1.878000  0.879417  0.91  1.0000
# GALA                               325.0  3.021692  1.237459  0.99  1.9500
# FUJI                               260.0  2.799808  1.207006  1.11  1.7875
# HONEYCRISP                         170.0  3.407824  1.333460  1.82  2.3175
#
#
#                          50%     75%   max
# variety
# ROME                   2.000  2.7075  3.98
# GINGER GOLD            2.500  2.7000  4.99
# JONATHAN               2.550  2.9900  3.99
# PINK LADY/CRIPPS PINK  2.110  3.8400  6.99
# MCINTOSH               2.270  2.8000  6.99
# BRAEBURN               1.645  2.9900  5.00
# GRANNY SMITH           2.990  3.9900  6.99
# JONAGOLD               1.745  2.5000  5.99
# GOLDEN DELICIOUS       2.170  2.9900  4.98
# RED DELICIOUS          2.860  3.5000  6.99
# PAULA RED              1.990  2.5750  3.17
# GALA                   3.120  3.9100  6.99
# FUJI                   2.800  3.6925  8.13
# HONEYCRISP             2.965  3.9900  6.99

# %% [markdown]
# ## Transforming and adding columns
# The date column in this data is a US formatted string, there are two ways to deal with that

# %%
(nat_apples
 
 # create two new columns datetime and date_str 
 # store dates in those formats there
 .assign(
     datetime=lambda x: pd.to_datetime(x.date,format="%m/%d/%Y"),
     date_str=lambda x: pd.to_datetime(x.date,format="%m/%d/%Y").dt.strftime("%Y-%m-%d")
 )
 
 # new columns are put at the end of a dataframe.
 # I'm limiting the columns so that you can see them
 [["date", "datetime", "date_str", "number_of_stores"]]
 
).head()
# Out:
#          date   datetime    date_str  number_of_stores
# 1  09/07/2018 2018-09-07  2018-09-07                53
# 2  09/07/2018 2018-09-07  2018-09-07                55
# 3  09/07/2018 2018-09-07  2018-09-07               593
# 4  09/07/2018 2018-09-07  2018-09-07              1349
# 5  09/07/2018 2018-09-07  2018-09-07                59

# %% [markdown]
# **It's also helpful to extract data or reformat it.**
#
# let's add a column to indicate what the volume of the unit is

# %%
# define a function to do the conversion
def unit_to_vol(n):
    """convert a unit of 'per pound' or 'N pound bag' to an int of lbs"""
    if 'bag' not in n:
        return 1
    else:
        # parse 'N pound bag' by string splitting
        return int(float(n.split(" ")[0]))
                                                             
(nat_apples
 
 # add a column that is the unit volume
 .assign(
     unit_vol=lambda x: x.unit.map(unit_to_vol)
 )
 
 # new columns are put at the end of a dataframe.
 # I'm limiting the columns so that you can see them
 [["date", "variety", "unit", "unit_vol"]]
 
).head()
# Out:
#          date   variety       unit  unit_vol
# 1  09/07/2018  BRAEBURN  per pound         1
# 2  09/07/2018      FUJI   2 lb bag         2
# 3  09/07/2018      FUJI   3 lb bag         3
# 4  09/07/2018      FUJI  per pound         1
# 5  09/07/2018      FUJI  per pound         1

# %% [markdown]
# ## Putting it all together
# Let's put this all together to start from the raw data, rename the columns, and select fuji apples

# %%
fuji_df = (df
     # clean up the column names
    .rename(columns=lambda x: x.replace("% ", ""))
    .rename(columns=str.lower)
    .rename(columns=lambda x: x.replace(" ", "_"))
    
    # convert the date column into datetimes 
    .assign(
        date=lambda x: pd.to_datetime(x.date, format="%m/%d/%Y"),
        unit_vol=lambda x: x.unit.map(unit_to_vol)
    )
    
    # add a per_pound price, we do this in a separate assign
    # because it relies on something calculated in the first
    .assign(
        weighted_avg_price_pp=lambda x: x.weighted_avg_price / x.unit_vol,
        low_price_pp=lambda x: x.low_price / x.unit_vol,
        high_price_pp=lambda x: x.high_price / x.unit_vol
    )
 
     # limit to Fuji Apples
    .query("commodity == 'APPLES' & variety == 'FUJI'")
           
     # limit to only non-organic
    .query("organic != 'Y'")
           
     # make sure the dates are in chronological order
    .sort_values("date", ascending=False)
     
     # only keep the columns we want
    [["date", "region", "number_of_stores", "weighted_avg_price_pp", "low_price_pp", "high_price_pp", "unit"]]
)

fuji_df.head()
# Out:
#             date              region  number_of_stores  weighted_avg_price_pp  \
# 86195 2019-08-30              HAWAII                13                   1.63
# 86045 2019-08-30      NORTHWEST U.S.                 5                   1.29
# 85844 2019-08-30      SOUTHWEST U.S.                88                   0.68
# 85674 2019-08-30  SOUTH CENTRAL U.S.                25                   0.82
# 85460 2019-08-30        MIDWEST U.S.               146                   1.39
#
#        low_price_pp  high_price_pp       unit
# 86195          1.48           1.79  per pound
# 86045          1.29           1.29  per pound
# 85844          0.49           0.77  per pound
# 85674          0.59           1.29  per pound
# 85460          0.99           1.49  per pound

# %% [markdown]
# ### Where and when were the most expensive Fuji apples marketed? Cheapest? How were they sold?

# %%
fuji_expen = (fuji_df
    # sort the data high to low
    .sort_values("high_price_pp", ascending=False)
    
    # limit to the top 10
    .head(5)
    
    # limit the columns
    [["date", "region", "high_price_pp", "unit"]]
)

fuji_cheap = (fuji_df
    # sort the data low to high
    .sort_values("low_price_pp")
    
    # limit to the top 10
    .head(5)
    
    # limit the columns
    [["date", "region", "low_price_pp", "unit"]]
)

display(fuji_expen)
display(fuji_cheap)
# Out:
#             date          region  high_price_pp       unit
# 43125 2019-02-22          HAWAII           3.99  per pound
# 17714 2018-11-09          HAWAII           3.49  per pound
# 15970 2018-11-02          HAWAII           3.49  per pound
# 46480 2019-03-08          HAWAII           2.99  per pound
# 41065 2019-02-15  SOUTHWEST U.S.           2.99  per pound
#             date          region  low_price_pp       unit
# 24104 2018-12-07  SOUTHWEST U.S.          0.33  per pound
# 15162 2018-11-02    MIDWEST U.S.          0.33   3 lb bag
# 44452 2019-03-01  SOUTHWEST U.S.          0.33   3 lb bag
# 54385 2019-04-12  SOUTHWEST U.S.          0.33  per pound
# 13828 2018-10-26  SOUTHWEST U.S.          0.33  per pound

# %% [markdown]
# ## Pivoting the data (and more)
#
# #### How did the price Fuji apples sold per pound change in average price over the course of the year? How did the national average compare to the Northwest US?

# %%
us_vs_nw_fuji = (fuji_df
 
 # limit to per pound sales
 .query("unit == 'per pound'")
 
 # limit to National and Northwest
 .query("region == 'NATIONAL' | region == 'NORTHWEST U.S.'")
 
 # pivot the data on date and region, use avg_price
 .pivot(
        index="date", 
        columns="region", 
        values="weighted_avg_price_pp"
  )
 
 # create a new column that is the difference of the National and NW price
 .assign(
     nat_nw_diff=lambda x: x["NORTHWEST U.S."] - x["NATIONAL"]
 )
 
 
)

(us_vs_nw_fuji
 
     # Do something fancy!
     # color the cells when Fuji's were more expensive than the national average
     .style.applymap(
         lambda x: "background-color: lightyellow; font-weight: bold;" if x > 0 else "", 
         subset=["nat_nw_diff"]
     )
)
# Out:
# <style  type="text/css" >
#     #T_e8490f64_de68_11e9_821f_a45e60b9880drow1_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow2_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow3_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow4_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow5_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow10_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow11_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow18_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow20_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow21_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow25_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow26_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow33_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow35_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow37_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow45_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow47_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }    #T_e8490f64_de68_11e9_821f_a45e60b9880drow48_col2 {
#             background-color:  lightyellow;
#              font-weight:  bold;
#         }</style><table id="T_e8490f64_de68_11e9_821f_a45e60b9880d" ><thead>    <tr>        <th class="index_name level0" >region</th>        <th class="col_heading level0 col0" >NATIONAL</th>        <th class="col_heading level0 col1" >NORTHWEST U.S.</th>        <th class="col_heading level0 col2" >nat_nw_diff</th>    </tr>    <tr>        <th class="index_name level0" >date</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8490f64_de68_11e9_821f_a45e60b9880dlevel0_row0" class="row_heading level0 row0" >2018-09-07 00:00:00</th>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow0_col0" class="data row0 col0" >1.11</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow0_col1" class="data row0 col1" >0.99</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow0_col2" class="data row0 col2" >-0.12</td>
#             </tr>
#             <tr>
#                         <th id="T_e8490f64_de68_11e9_821f_a45e60b9880dlevel0_row1" class="row_heading level0 row1" >2018-09-14 00:00:00</th>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow1_col0" class="data row1 col0" >1.17</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow1_col1" class="data row1 col1" >1.4</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow1_col2" class="data row1 col2" >0.23</td>
#             </tr>
#             <tr>
#                         <th id="T_e8490f64_de68_11e9_821f_a45e60b9880dlevel0_row2" class="row_heading level0 row2" >2018-09-21 00:00:00</th>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow2_col0" class="data row2 col0" >1.15</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow2_col1" class="data row2 col1" >1.18</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow2_col2" class="data row2 col2" >0.03</td>
#             </tr>
#             <tr>
#                         <th id="T_e8490f64_de68_11e9_821f_a45e60b9880dlevel0_row3" class="row_heading level0 row3" >2018-09-28 00:00:00</th>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow3_col0" class="data row3 col0" >1.32</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow3_col1" class="data row3 col1" >1.5</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow3_col2" class="data row3 col2" >0.18</td>
#             </tr>
#             <tr>
#                         <th id="T_e8490f64_de68_11e9_821f_a45e60b9880dlevel0_row4" class="row_heading level0 row4" >2018-10-05 00:00:00</th>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow4_col0" class="data row4 col0" >1.2</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow4_col1" class="data row4 col1" >1.27</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow4_col2" class="data row4 col2" >0.07</td>
#             </tr>
#             <tr>
#                         <th id="T_e8490f64_de68_11e9_821f_a45e60b9880dlevel0_row5" class="row_heading level0 row5" >2018-10-12 00:00:00</th>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow5_col0" class="data row5 col0" >1.14</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow5_col1" class="data row5 col1" >1.38</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow5_col2" class="data row5 col2" >0.24</td>
#             </tr>
#             <tr>
#                         <th id="T_e8490f64_de68_11e9_821f_a45e60b9880dlevel0_row6" class="row_heading level0 row6" >2018-10-19 00:00:00</th>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow6_col0" class="data row6 col0" >1.37</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow6_col1" class="data row6 col1" >0.78</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow6_col2" class="data row6 col2" >-0.59</td>
#             </tr>
#             <tr>
#                         <th id="T_e8490f64_de68_11e9_821f_a45e60b9880dlevel0_row7" class="row_heading level0 row7" >2018-10-26 00:00:00</th>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow7_col0" class="data row7 col0" >1.35</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow7_col1" class="data row7 col1" >1.07</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow7_col2" class="data row7 col2" >-0.28</td>
#             </tr>
#             <tr>
#                         <th id="T_e8490f64_de68_11e9_821f_a45e60b9880dlevel0_row8" class="row_heading level0 row8" >2018-11-02 00:00:00</th>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow8_col0" class="data row8 col0" >1.39</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow8_col1" class="data row8 col1" >1.37</td>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow8_col2" class="data row8 col2" >-0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_e8490f64_de68_11e9_821f_a45e60b9880dlevel0_row9" class="row_heading level0 row9" >2018-11-09 00:00:00</th>
#                         <td id="T_e8490f64_de68_11e9_821f_a45e60b9880drow9_co

# %% [markdown]
# ## Saving your data

# %%
us_vs_nw_fuji.to_csv("us-vs-nw-fuji-apples-201809-201909.csv")

# %% [markdown]
# ## Joining data
# Let's load up some new data from the USDA and US Census about avocados to join import figures with retail prices

# %%
# load the retail data
avo_retail = (df
     # clean up the column names
    .rename(columns=lambda x: x.replace("% ", ""))
    .rename(columns=str.lower)
    .rename(columns=lambda x: x.replace(" ", "_"))
    
    # convert the date column into datetimes 
    .assign(
        date=lambda x: pd.to_datetime(x.date, format="%m/%d/%Y"),
        unit_vol=lambda x: x.unit.map(unit_to_vol)
    )
              
    .assign(
       # create a column that's a year and month string
       year_month=lambda x: x.date.dt.strftime("%Y-%m")
   )
              
    # limit to Hass Avocados
   .query("commodity == 'AVOCADOS' & variety == 'HASS'")
             
    # limit to the National aggregation
   .query("region == 'NATIONAL'")
             
   # limit to item sales
   .query("unit == 'each'")
          
    # limit to only non-organic
   .query("organic != 'Y'")
          
    # make sure the dates are in chronological order
   .sort_values("date", ascending=False)
    
    # only keep the columns we want
   [["date", "year_month", "number_of_stores", "weighted_avg_price"]]
)

# load the imports data
avo_imports = (pd.read_csv("census-us-imports-avocados-201805-201907.csv")
                     
   .assign(
       # convert the time column to a parsed date  
       date=lambda x: pd.to_datetime(x.time),
   )
               
   .assign(
       # create a column that's a year and month string
       year_month=lambda x: x.date.dt.strftime("%Y-%m")
   )
               
   # drop the blank column and the string date column
   .drop(["Unnamed: 4", "time"], axis=1)

  )

display(avo_retail.head())
display(avo_imports.head())
# Out:
#             date year_month  number_of_stores  weighted_avg_price
# 84756 2019-08-30    2019-08              6163                1.28
# 83164 2019-08-23    2019-08              8155                1.11
# 81647 2019-08-16    2019-08              4688                1.18
# 80125 2019-08-09    2019-08              4657                1.36
# 78539 2019-08-02    2019-08              7790                1.06
#      gen_val   gen_qty  gen_unit_val       date year_month
# 0  277140118  83002869          3.34 2019-07-01    2019-07
# 1  212474553  56398177          3.77 2019-06-01    2019-06
# 2  253722506  75525694          3.36 2019-05-01    2019-05
# 3  303105601  87379294          3.47 2019-04-01    2019-04
# 4  199917909  99982135          2.00 2019-03-01    2019-03

# %% [markdown]
# Now let's join them on the `year_month` column.
#
# Generally, you'll use `merge` to join data frames on arbitrary columns

# %%
(avo_retail
 .merge(avo_imports,
    # join using the year_month column
    on="year_month",
    
    # do a left outer join
    how="left",
    
    # where the columns overlap, add a suffix to 
    # make clear which frame it came from
    suffixes=["_retail", "_imports"]
 )
).tail()
# Out:
#    date_retail year_month  number_of_stores  weighted_avg_price      gen_val  \
# 47  2018-10-05    2018-10              6780                1.09  168443666.0
# 48  2018-09-28    2018-09              8280                1.18  177933537.0
# 49  2018-09-21    2018-09              6640                1.15  177933537.0
# 50  2018-09-14    2018-09              6523                1.16  177933537.0
# 51  2018-09-07    2018-09              2978                1.25  177933537.0
#
#        gen_qty  gen_unit_val date_imports
# 47  83302581.0          2.02   2018-10-01
# 48  75976150.0          2.34   2018-09-01
# 49  75976150.0          2.34   2018-09-01
# 50  75976150.0          2.34   2018-09-01
# 51  75976150.0          2.34   2018-09-01

# %% [markdown]
# However your data might share an index, rather than a column

# %%
# set `year_month` as an index for the example
avo_retail_ind = avo_retail.set_index("year_month")
avo_imports_ind = avo_imports.set_index("year_month")

display(avo_retail_ind.head(2))
display(avo_imports_ind.head(2))
# Out:
#                  date  number_of_stores  weighted_avg_price
# year_month
# 2019-08    2019-08-30              6163                1.28
# 2019-08    2019-08-23              8155                1.11
#               gen_val   gen_qty  gen_unit_val       date
# year_month
# 2019-07     277140118  83002869          3.34 2019-07-01
# 2019-06     212474553  56398177          3.77 2019-06-01

# %% [markdown]
# Now joining these frames is even simpler

# %%
(avo_retail_ind
   .join(avo_imports_ind, 
         lsuffix="_retail", 
         rsuffix="_imports"
    )
).head()
# Out:
#            date_retail  number_of_stores  weighted_avg_price      gen_val  \
# year_month
# 2018-09     2018-09-28              8280                1.18  177933537.0
# 2018-09     2018-09-21              6640                1.15  177933537.0
# 2018-09     2018-09-14              6523                1.16  177933537.0
# 2018-09     2018-09-07              2978                1.25  177933537.0
# 2018-10     2018-10-26             13631                0.97  168443666.0
#
#                gen_qty  gen_unit_val date_imports
# year_month
# 2018-09     75976150.0          2.34   2018-09-01
# 2018-09     75976150.0          2.34   2018-09-01
# 2018-09     75976150.0          2.34   2018-09-01
# 2018-09     75976150.0          2.34   2018-09-01
# 2018-10     83302581.0          2.02   2018-10-01
